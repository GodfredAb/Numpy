# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
age_of_students = np.arange(17, 30)

# %%
plt.title("Age of university students")
plt.plot(age_of_students)
plt.show()

# %%
age = np.linspace(16, 30)

# %%
plt.title("Age")
plt.plot(age)
plt.show()

# %%
# one dimensional array
one = np.arange(10)
print(one[2])
print(one[:5])
# Out:
# 2
# [0 1 2 3 4]

# %%
# two dimensional array
two, spacing = np.linspace(0, 10, endpoint=False,retstep=True)
